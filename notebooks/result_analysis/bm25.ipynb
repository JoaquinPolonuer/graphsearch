# %%
import json
import pandas as pd
import sys

sys.path.append("../../")

from config import DATA_DIR
from graph_types.graph import Graph

graph_name = "mag"

# %%
logs_dir = DATA_DIR / f"experiments/{graph_name}/bm25"
json_files = sorted([f for f in logs_dir.glob("*.json")], key=lambda x: x.stat().st_ctime)

data = []

for json_file in json_files:
    with open(json_file, "r") as f:
        log_data = json.load(f)

    # Extract key information from each log entry
    record = {
        "file_id": int(json_file.stem),
        "question": log_data.get("question", ""),
        "answer_indices": log_data.get("answer_indices", []),
        "bm25_indices": log_data.get("bm25_indices", []),
    }

    data.append(record)

df = pd.DataFrame(data).reset_index(drop=True)  # .sort_values(by="file_id").reset_index(drop=True)

df["recall@all"] = df.apply(
    lambda row: len(set(row["answer_indices"]).intersection(set(row["bm25_indices"])))
    / len(set(row["answer_indices"])),
    axis=1,
)
df["hit@1"] = df.apply(
    lambda row: (row["bm25_indices"][0] in row["answer_indices"] if row["bm25_indices"] else False),
    axis=1,
)
df["hit@5"] = df.apply(
    lambda row: len(set(row["answer_indices"]).intersection(set(row["bm25_indices"][:5]))) > 0,
    axis=1,
)
df["hit@10"] = df.apply(
    lambda row: len(set(row["answer_indices"]).intersection(set(row["bm25_indices"][:10]))) > 0,
    axis=1,
)
df["recall@10"] = df.apply(
    lambda row: len(set(row["answer_indices"]).intersection(set(row["bm25_indices"][:10])))
    / len(set(row["answer_indices"])),
    axis=1,
)
df["recall@20"] = df.apply(
    lambda row: len(set(row["answer_indices"]).intersection(set(row["bm25_indices"][:20])))
    / len(set(row["answer_indices"])),
    axis=1,
)

[
    ("n", len(df)),
    ("Hit@1", float(round(df["hit@1"].mean(), 3))),
    ("Hit@5", float(round(df["hit@5"].mean(), 3))),
    ("Recall@10", float(round(df["recall@10"].mean(), 3))),
    ("Recall@20", float(round(df["recall@20"].mean(), 3))),
    ("Recall@all", float(round(df["recall@all"].mean(), 3))),
]
# Out:
# [('n', 1000),
#  ('Hit@1', 0.229),
#  ('Hit@5', 0.433),
#  ('Recall@10', 0.385),
#  ('Recall@20', 0.456),
#  ('Recall@all', 0.606)]

# %%
try:
    graph
except NameError:
    graph = Graph.load(graph_name)

# %%
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
for _, row in df[df["recall@20"] == 0].iterrows():
    print(f"File ID: {row['file_id']}")
    print(f"Question: {row['question']}")

    bm25_indices = row["bm25_indices"]
    nodes = [graph.get_node_by_index(idx) for idx in bm25_indices][:10]
    print("bm25 Nodes:", "\n".join([node.name for node in nodes]))

    print()
# Out:
# File ID: 737
# Question: Find papers on the development of optical imaging methods that are referenced in "Fluorescence and SEM correlative microscopy for nanomanipulation of subcellular structures".
# bm25 Nodes: Fluorescence and SEM correlative microscopy for nanomanipulation of subcellular structures
# Superresolution optical fluctuation imaging (SOFI) aided nanomanipulation of quantum dots using AFM for novel artificial arrangements of chemically functionalized colloidal quantum dots and plasmonic structures
# Super-resolution endoscopy for real-time wide-field imaging
# Combined multi-plane phase retrieval and super-resolution optical fluctuation imaging for 4D cell microscopy.
# Fluorescence and second-harmonic generation correlative microscopy to probe space charge separation and silver cluster stabilization during direct laser writing in a tailored silver-containing glass
# The 2018 correlative microscopy techniques roadmap.
# Development of functional nanoprobes for optical near-field characterization.
# Fluorescence lifetime imaging microscopy in life sciences
# Subcellular spatial resolution achieved for deep-brain imaging in vivo using a minimally invasive multimode fiber.
# Phase and fluorescence imaging by combination of digital holographic microscopy and fluorescence microscopy
#
# File ID: 660
# Question: Which publications by the authors of "InN PHOTOCONDUCTORS ON DIFFERENT ORIENTATIONS OF Si SUBSTRATES" delve into InGaN quantum well lasers?
# bm25 Nodes: InN PHOTOCONDUCTORS ON DIFFERENT ORIENTATIONS OF Si SUBSTRATES
# Stranski-Krastanov InN/InGaN quantum dots grown directly on Si(111)
# InN p-i-n Nanowire Solar Cells on Si
# Investigation of optical properties of InGaN–InN–InGaN/GaN quantum-well in the green spectral regime
# Growth mechanism and microstructure of low defect density InN (0001) In-face thin films on Si (111) substrates
# InN/GaN alternative growth of thick InGaN wells on GaN-based light emitting diodes
# High-quality InN films on GaN using graded InGaN buffers by MBE
# InN/InGaN multiple quantum wells emitting at 1.5 μm grown by molecular beam epitaxy
# Quantum well engineering in InGaN/GaN core-shell nanorod structures
# Near-infrared InN quantum dots on high-In composition InGaN
#
# File ID: 859
# Question: 2013 publications from Eastern Illinois University on the topic of atomic coherence
# bm25 Nodes: Eastern Illinois University
# Universal ac conduction in large area atomic layers of CVD-grown MoS2
# Effects of spin on magnetized binary neutron star mergers and jet launching
# University of Illinois System
# University of Illinois at Chicago
# University of Illinois at Springfield
# University of Illinois at Urbana–Champaign
# Numerical study of steam condensation inside a long inclined flattened channel
# Northeastern Illinois University
# Illinois State University
#
# File ID: 811
# Question: Have any research papers assessing sensor technologies been published by scholars from the Kuwait Institute for Scientific Research?
# bm25 Nodes: Kuwait Institute for Scientific Research
# The science of science: from the perspective of complex systems
# Efficient, nanosecond self-Q-switched Cr,Yb:YAG lasers by bonding Yb:YAG crystal
# Comparative study on enhancement of self-Q-switched Cr,Yb:YAG lasers by bonding Yb:YAG ceramic and crystal
# Focus on integrated quantum optics
# Peter Waterman and his scientific legacy
# Peer Review of Datasets: When, Why, and How
# Observational evidence for extended emission to GW170817
# Guest Editorial The Past, Present, and Future of Electromagnetic Launch Technology and the IEEE International EML Symposia
# Fiber Lasers of Prof. Okhotnikov: Review of the Main Achievements and Breakthrough Technologies
#
# File ID: 973
# Question: What are some related articles that discuss the efficiency of diamond nanowires and have cited or been referenced in the study "Designs for high-efficiency electrically pumped photonic nanowire single-photon sources"?
# bm25 Nodes: Designs for high-efficiency electrically pumped photonic nanowire single-photon sources
# Single photon emission from positioned GaAs/AlGaAs photonic nanowires
# A highly efficient single-photon source based on a quantum dot in a photonic nanowire
# Bright nanowire single photon source based on SiV centers in diamond
# Design of polarization-insensitive superconducting single photon detectors with high-index dielectrics
# Waveguide photon-number-resolving detectors for quantum photonic integrated circuits
# Quantum optics: Towards efficient quantum sources
# Electrically Driven Quantum Dot Micropillar Light Sources
# Solar power conversion efficiency in modulated silicon nanowire photonic crystals
# High repetition rate correlated photon pair generation in integrated silicon nanowires.
#
# File ID: 899
# Question: Show me articles related to the study of Virga effects on the generation of clouds by airplanes.
# bm25 Nodes: The effects of interface misfit strain and surface tension on magnetoelectric effects in layered magnetostrictive-piezoelectric composites
# Nonlinear magnetoelectric effects at high magnetic field amplitudes in composite multiferroics
# Doping effects on the magnetoelectricity of bismuth ferrite nanoparticles
# Magnetoelectric effect in layered ferrite/PZT composites. Study of the demagnetizing effect on the magnetoelectric behavior
# Modeling of magnetoelectric effects in flexural nanobilayers: The effects of surface stress
# First-principles approach to the dynamic magnetoelectric couplings for the non-reciprocal directional dichroism in BiFeO3
# Nonlinear magnetoelectric effect in PZT/Terfenol-D nanobilayer on a substrate with surface stress
# Progress in studying ferroelectromagnetic crystals
# The evolution of airplanes
# Emergent odd-parity multipoles and magnetoelectric effects on a diamond structure: Implication for the 5 d transition metal oxides A OsO 4 ( A = K , Rb , and Cs )
#
# File ID: 319
# Question: Are there any image processing research papers from Dongseo University suggesting a novel high-resolution 3D imaging system?
# bm25 Nodes: Study on real time 3D imaging of streak tube lidar based on LabVIEW
# Resolution enhanced 3D image reconstruction by use of ray tracing and auto-focus in computational integral imaging
# Three-dimensional light field microscope based on a lenslet array
# Spatial-resolution analysis and optimal design of integral imaging
# Imaging systems and applications.
# Analysis of the features and reconstruction of a high resolution infrared image based on a multi-aperture imaging system
# Three-dimensional resolvability in an integral imaging system
# Millimeter-wave spotlight imager using dynamic holographic metasurface antennas
# Heterodyne 3D ghost imaging
# Three-dimensional imaging based on electronically adaptive liquid crystal lens
#
# File ID: 174
# Question: Which publications by authors affiliated with the National Institute of Amazonian Research focus on the thermodynamics of boundary layers?
# bm25 Nodes: National Institute of Amazonian Research
# Focus on quantum thermodynamics
# The nature of the faint low-frequency radio source population
# A low upper-mass limit for the central black hole in the late-type galaxy NGC 4414
# Search for Eccentric Binary Black Hole Mergers with Advanced LIGO and Advanced Virgo during Their First and Second Observing Runs
# Search for intermediate mass black hole binaries in the first and second observing runs of the Advanced LIGO and Virgo network
# Contributions of the Pulkovo and Kharkiv Scientific Schools to the search for exoplanets and low-mass dark satellites of stars
# Search for Tensor, Vector, and Scalar Polarizations in the Stochastic Gravitational-Wave Background
# Influence of the ion wake-field on the eikonal cross section for the electron–dust collision in dusty plasmas
# Cooperation and coauthorship in scientific publishing.
#
# File ID: 527
# Question: I'm looking for papers related to strong field ionization and are in the same field as "Insights from the classical atom". They should also share at least one coauthor with it. The goal is to explore more work from these authors that could offer further understanding on this topic from a similar lens.
# bm25 Nodes: Dynamics of an atomic system in a strong non-classical electromagnetic field
# Melting of scalar hadrons in an AdS/QCD model modified by a thermal dilaton
# Emergent spacetime according to effective field theory: From top-down and bottom-up
# Toward the Discovery of Citation Cartels in Citation Networks
# New insights on pseudospin doublets in nuclei
# Reaching the optomechanical strong-coupling regime with a single atom in a cavity
# Dependence of carbon fragments from methane in strong and ultrastrong elliptically polarized laser fields
# Comparison of two forms of the S-matrix element of strong-field photoionization: II. (n, l, m) = (2, 1, ±1) states
# Calculation of state selective field ionization of hydrogen atoms in a strong magnetic field
# Could rogue waves be used as efficient weapons against enemy ships
#
# File ID: 235
# Question: Are there any Astrophysics papers related to Saturn's co-orbital satellites connected with Beloit College?
# bm25 Nodes: Beloit College
# The role of tidal torques on the evolution of the system of Saturn’s co-orbital satellites Janus and Epimetheus
# Frequency-dependent tidal dissipation in a viscoelastic Saturnian core and expansion of Mimas' semi-major axis
# The Hungaria region as a possible source of Trojans and satellites in the inner Solar system
# The recent formation of Saturn's moonlets from viscous spreading of the main rings
# Stability of co-orbital ring material with applications to the Janus-Epimetheus system
# Co-orbital satellites of Saturn: congenital formation
# Detection of co-orbital planets by combining transit and radial-velocity measurements
# Periodic orbits for three and four co-orbital bodies
# The propeller and the frog
#
# File ID: 101
# Question: Do any publications from Algoma University examine high-loop quantum electrodynamics (QED) amplitudes in the context of gauge theories, and not gauge as in firearms?
# bm25 Nodes: Gauge-free Coleman–Weinberg potential
# Loop amplitudes in gauge theories: modern analytic approaches
# Hopf-algebraic Renormalization of QED in the linear covariant Gauge
# New BCJ representations for one-loop amplitudes in gauge theories and gravity
# 2PI functional techniques for gauge theories: QED
# String-motivated one-loop amplitudes in gauge theories with half-maximal supersymmetry
# Consistency of loop regularization method and divergence structure of QFTs Beyond one-loop order
# Next-to-simplest quantum field theories
# Gauge invariant 1PI effective superstring field theory: inclusion of the Ramond sector
# One-loop amplitudes in six-dimensional (1,1) theories from generalised unitarity
#
# File ID: 986
# Question: What publications mentioning the exploration of new physics via detailed beta decay experiments have cited the study "Limits on tensor-type weak currents from nuclear and neutron β decays"?
# bm25 Nodes: Limits on tensor-type weak currents from nuclear and neutron β decays
# Prospects for precision measurements in nuclear β decay in the LHC era
# Measurement of the eta$-asymmetry parameter of $^{67}$Cu in search for tensor-type currents in the weak interaction
# Weak interaction physics at ISOLDE
# β-decay angular correlations with neutral atom traps
# Double beta decays and neutrino nuclear responses
# Theoretical studies of rare weak processes in nuclei
# Value of the Axial-Vector Coupling Strength in β and ββ Decays: A Review
# New physics effects on neutrinoless double beta decay from right-handed current
# Total Absorption Study of Beta Decays Relevant for Nuclear Applications and Nuclear Structure
#
# File ID: 499
# Question: Are there any research papers on proton-nucleus scattering published by scholars from Kyushu Dental University?
# bm25 Nodes: Kyushu Dental University
# Observation of Nonlinear Coupling between Low Frequency Coherent Modes and Background Turbulence in LMD-U
# Experimental Investigations of Discrepancies in Three-Nucleon Reactions
# Ion-proton pulsars
# Comparative study on enhancement of self-Q-switched Cr,Yb:YAG lasers by bonding Yb:YAG ceramic and crystal
# New approach to determine proton-nucleus interactions from experimental bremsstrahlung data
# Efficient, nanosecond self-Q-switched Cr,Yb:YAG lasers by bonding Yb:YAG crystal
# Kyushu University
# Systematic CDCC calculations for 11 Be + p elastic scattering
# Kyushu Kyoritsu University
#
# File ID: 687
# Question: Could you please find me any papers discussing neutrino properties at electroweak scale temperatures, written by co-authors of the paper titled 'Longitudinal Conductivity in Strong Magnetic Field in Perturbative QCD: Complete Leading Order'?
# bm25 Nodes: Longitudinal Conductivity in Strong Magnetic Field in Perturbative QCD: Complete Leading Order
# The complete NLO corrections to dijet hadroproduction
# Charged current neutrino-nucleon total cross section at high energies
# Conductivities of magnetic quark-gluon plasma at strong coupling
# Examining the neutrino option
# DETERMINATION OF THE STRONG COUPLING CONSTANT FROM NLO QCD ANALYSIS OF PROTON STRUCTURE FUNCTION
# Monte Carlo modelling of NLO DGLAP QCD Evolution in the fully unintegrated form
# Dilepton and photon production in the presence of a nontrivial Polyakov loop
# Lattice QCD and Neutrino-Nucleus Scattering
# Polarized hyperon production in single-inclusive electron-positron annihilation at next-to-leading order
#
# File ID: 584
# Question: Are there any 2016 papers in the field of Optics from North China University of Technology that contribute to resolution improvement?
# bm25 Nodes: Dynamic downscaling of summer precipitation prediction over China in 1998 using WRF and CCSM4
# North China University of Technology
# The Development of EML Technology in China
# North China University of Science and Technology
# Trends and Variability in Aerosol Optical Depth over North China from MODIS C6 Aerosol Products during 2001–2016
# Fiber guiding at the Dirac frequency beyond photonic bandgaps
# A closer looking at dimming and brightening in China during 1961-2005
# Ranking Regional Drought Events in China for 1960-2009
# Seasonal Responses of Precipitation in China to El Niño and Positive Indian Ocean Dipole Modes
# Variations of the ionospheric TEC using simultaneous measurements from the China Crustal Movement Observation Network
#
# File ID: 59
# Question: Looking for research articles that have a co-author in common with "Chaplygin gas of Tachyon Nature Imposed by Noether Symmetry and constrained via $H(z)$ data", that are also within the same field, and provide similar comparative analysis of modified gravity models as alternatives to traditional cosmology models.
# bm25 Nodes: Chaplygin gas of Tachyon Nature Imposed by Noether Symmetry and constrained via $H(z)$ data
# Some exact solutions in f(,T) gravity via Noether symmetries
# Constraints and analytical solutions of $f(R)$ theories of gravity using Noether symmetries
# Dark energy cosmology with tachyon field in teleparallel gravity
# How effective is new variable modified Chaplygin gas to play the role of dark energy- A dynamical system analysis in RS II Brane model
# Higher order corrections of the extended Chaplygin gas cosmology with varying G and \Lambda
# ROLE OF GENERALIZED COSMIC CHAPLYGIN GAS IN ACCELERATING UNIVERSE: A FIELD THEORETICAL PRESCRIPTION
# Chaplygin gas inspired scalar fields inflation via well-known potentials
# Using Noether symmetries to specify f(R) gravity
# Constraints on modified Chaplygin gas from large scale structure
#
# File ID: 312
# Question: What are the papers exploring six-dimensional supergravity solutions that are referenced in the study "A straight waveguide with a wire inducing resonances"?
# bm25 Nodes: A straight waveguide with a wire inducing resonances
# Electromagnetic Resonances of a Straight Wire
# Lifshitz black holes in IIA supergravity
# Exact half-BPS string-junction solutions in six-dimensional supergravity
# The nuts and bolts of Einstein-Maxwell solutions
# Supersymmetric solutions to Euclidean Romans supergravity
# Electromagnetic Resonances of a Straight Wire on an Earth-Air Interface
# Entanglement entropy of Wilson surfaces from bubbling geometries in M-theory
# A note on supersymmetric AdS6 solutions of massive type IIA supergravity
# BPS Solutions of Six-Dimensional (1,0) Supergravity Coupled to Tensor Multiplets
#
# File ID: 277
# Question: Find research articles exploring energy transfer characteristics cited in the study titled 'Spectroscopic properties and quenching mechanism of 2 μm emission in Ho^3+ doped germanate glasses and fibers'.
# bm25 Nodes: Spectroscopic properties and quenching mechanism of 2 μm emission in Ho^3+ doped germanate glasses and fibers
# Enhanced 2.0 μm emission in Ho3+/Yb3+ co-doped silica-germanate glass
# Broadband 2 μm emission characteristics and energy transfer mechanism of Ho3+ doped silicate-germanate glass sensitized by Tm3+ ions
# Infrared emission properties and energy transfer between Tm 3+ and Ho 3+ in lanthanum aluminum germanate glasses
# Broadband 2 μm emission and energy-transfer properties of thulium-doped oxyfluoride germanate glass fiber
# Er 3+ doped germanate-tellurite glass for mid-infrared 2.7 μm fiber laser material
# Efficient 2.7 μm emission and energy transfer mechanism in Er3+ doped Y2O3 and Nb2O5 modified germanate glasses
# Efficient 2 µm emission in Nd3+/Ho3+ co-doped silicate-germanate glass pumped by common 808 nm LD
# Efficient ∼2 μm emission and energy transfer mechanism of Ho 3+ doped barium gallium germanate glass sensitized by Tm 3+ ions
# Infrared luminescence of Tm3+/Yb3+ codoped lanthanum aluminum germanate glasses
#
# File ID: 924
# Question: Show me publications by Guangwen Huo on the study of nanostructural changes and polarization effects in fused silica after laser irradiation.
# bm25 Nodes: Laser-induced periodic annular surface structures on fused silica surface
# High resolution characterization of modifications in fused silica after exposure to low fluence 355 nm laser at different repetition frequencies.
# High repetition rate femtosecond laser irradiation of fused silica studied by Raman spectroscopy
# Study of the Mechanism of Laser Etching Fused Silica Based on Barium Compound Powder Coating
# Optical characterization and laser damage of fused silica optics after ion beam sputtering
# Laser-welded fused silica substrates using a luminescent fresnoite-based sealant
# Investigation on Laser Damage Probability of Fused Silica with Simultaneous Multi-wavelength Irradiation
# Theoretical and experimental research on laser-induced damage of cylindrical subwavelength grating.
# Influence of oil contamination on the optical performance and laser induced damage of fused silica
# Ultrafast laser-induced birefringence in various porosity silica glasses: from fused silica to aerogel.
#
# File ID: 837
# Question: Publications by University of Texas Health Science Center at Tyler on bi-field influences in cosmological inflation models
# bm25 Nodes: University of Texas Health Science Center at Tyler
# University of Texas Health Science Center at Houston
# University of Texas Health Science Center at San Antonio
# University of North Texas Health Science Center
# Texas Tech University Health Sciences Center
# University of Texas at Tyler
# Texas A&M Health Science Center
# Cosmology from large-scale galaxy clustering and galaxy-galaxy lensing with dark energy survey science verification data
# PO2 dependant resistance switch effect in highly epitaxial (LaBa)Co2O5+δ thin films
# A consistent, scalable model for Eulerian spray modeling
#
# File ID: 10
# Question: Show me publications from the co-authors of "Carrier–envelope phase stabilization of 5-fs, 0.5-mJ pulses from adaptive phase modulator" that concentrate on or utilize microfabricated structures in their work.
# bm25 Nodes: Carrier–envelope phase stabilization of 5-fs, 0.5-mJ pulses from adaptive phase modulator
# Multi-mJ carrier envelope phase stabilized few-cycle pulses generated by a tabletop laser system
# Efficient hollow fiber compression scheme for generating multi-mJ, carrier-envelope phase stable, sub-5 fs pulses
# Carrier-Envelope Phase Control of Few-Cycle Parametric Chirped-Pulse Amplifier
# Carrier envelope phase stabilization of a Yb:KGW laser amplifier
# 1-mJ, sub-5-fs carrier–envelope phase-locked pulses
# Frequency comb based on a narrowband Yb-fiber oscillator: pre-chirp management for self-referenced carrier envelope offset frequency stabilization.
# 1 kHz, 1.6 μm high energy femtosecond pulses with self-stabilized carrier-envelope phases
# Few-cycle, carrier–envelope-phase-stable laser pulses from a compact supercontinuum source
# Generation of carrier-envelope phase-stable mid-infrared pulses via dual-wavelength optical parametric amplification.
#
# File ID: 221
# Question: Can you show me the papers that mention the discovery of a new SmCP phase and cite the article entitled "Synthesis and smectogenic properties of novel phloroglucinol-based star-shaped liquid crystals containing three peripheral alkyloxylated Schiff base arms?
# bm25 Nodes: Synthesis and smectogenic properties of novel phloroglucinol-based star-shaped liquid crystals containing three peripheral alkyloxylated Schiff base arms
# Star-shaped molecules as functional materials based on 1,3,5-benzenetriesters with pendant 1,3,4-thiadiazole groups: liquid crystals, optical, solvatofluorochromic and electrochemical properties
# Cholesteric star-shaped liquid crystals induced by a maltose core: synthesis and characteristics
# Synthesis and properties of novel columnar liquid crystals based on symmetrical and non-symmetrical 1,3,5-trisubstituted benzene derivatives
# Fabrication of conjugated polymeric nanochannels from star-shaped supramolecular liquid crystals containing two different photoreactive groups
# Synthesis of new schiff base ester liquid crystals with a benzothiazole core
# Liquid crystalline oligomers derived from cholesterol: synthesis and columnar mesomorphism
# Synthesis and mesomorphism of novel multi-arm liquid crystals with cholic acid as chiral centre linking Schiff base moieties as mesogens
# Oxadiazole-based unsymmetrical chiral liquid crystal dimers: synthesis and mesomorphic properties
# Columnar liquid crystalline tris-(ether)triazines with pendant 1,3,4-thiadiazole groups: synthesis, mesomorphic, luminescence, solvatofluorochromic and electrochemical properties
#
# File ID: 820
# Question: Are there any papers from Tabriz University of Medical Sciences that use computer modeling and simulations for radiation treatment room design?
# bm25 Nodes: Tabriz University of Medical Sciences
# AAPM TG 158: Measurement and calculation of doses outside the treated volume from external-beam radiation therapy.
# Safety considerations for IMRT
# On the neutron radiation field and air activation around a medical electron linac.
# Energy spectra in water for the 6 MV X-ray therapeutic beam generated by Clinac-2300 linac
# Connections between simulations and observation in climate computer modeling. Scientist’s practices and “bottom-up epistemology” lessons
# Simulation based planning of surgical interventions in pediatric cardiology.
# Microdosimetric comparison of scanned and conventional proton beams used in radiation therapy.
# University of Tabriz
# Overview of geometrical room acoustic modeling techniques
#
# File ID: 209
# Question: Are there any publications co-authored by someone from "Novel optical devices based on the tunable refractive index of magnetic fluid and their characteristics", which also focus on magnetic fluid refractive index tuning, especially in regards to temperature sensor applications?
# bm25 Nodes: Novel optical devices based on the tunable refractive index of magnetic fluid and their characteristics
# Temperature-Insensitive Magnetic Field Sensor Based on Nanoparticle Magnetic Fluid and Photonic Crystal Fiber
# Tunable Characteristics and Mechanism Analysis of the Magnetic Fluid Refractive Index With Applied Magnetic Field
# Thinned fiber Bragg grating magnetic field sensor with magnetic fluid
# Magneto-optical fiber sensor based on bandgap effect of photonic crystal fiber infiltrated with magnetic fluid
# Novel optical devices based on the transmission properties of magnetic fluid and their characteristics
# A novel optical fiber magnetic field sensor based on Mach-Zehnder interferometer integrated with magnetic fluid
# Optical sensing characteristics of the photonic crystal fiber filled with magnetic fluid
# Fiber in-line magnetic field sensor based on Mach-Zehnder interferometer integrated with magnetic fluid
# Refractive index sensor based on a polymer fiber directional coupler for low index sensing.
#
# File ID: 866
# Question: Search for publications that have a common author with the paper titled "Photometric and spectroscopic observations of three rapidly rotating late-type stars: EY Dra, V374 Peg, and GSC 02038-00293†", belong to the same research domain, and discuss a nova event in 2010, specifically V2491 Cyg.
# bm25 Nodes: Photometric and spectroscopic observations of three rapidly rotating late-type stars: EY Dra, V374 Peg, and GSC 02038-00293†
# Swift observations of the X-ray and UV evolution of V2491 Cyg (Nova Cyg 2008 No. 2)
# Spectroscopic study of the envelopes of the novae V2467 Cyg and V2491 Cyg
# An extensive optical study of V2491 Cyg (Nova Cyg 2008 N.2), from maximum brightness to return to quiescence
# Recent photometry of symbiotic stars - XIII
# LITHIUM ABUNDANCES FROM OPTICAL HIGH-RESOLUTION SPECTROSCOPY OF WEAK-LINE T TAURI STARS
# Suzaku Observation of the Classical Nova V2491 Cyg in Quiescence
# AN ACTIVITY–ROTATION RELATIONSHIP AND KINEMATIC ANALYSIS OF NEARBY MID-TO-LATE-TYPE M DWARFS
# Notices to investigation of symbiotic binaries V. Physical parameters derived from UBV magnitudes
# New powerful outburst of the unusual young star V1318 Cyg S (LkH{lpha} 225)
#
# File ID: 70
# Question: Show me publications by Daifa Wang on reconstructive techniques in fluorescence molecular tomography.
# bm25 Nodes: Daifa Wang
# Daifa Wang
# A parallel adaptive finite element simplified spherical harmonics approximation solver for frequency domain fluorescence molecular imaging
# Imaging of molecular probe activity with Born-normalized fluorescence optical projection tomography
# Non-uniqueness in fluorescence-enhanced continuous wave diffuse optical tomography
# Activatable thermo-sensitive ICG encapsulated pluronic nanocapsules for temperature sensitive fluorescence tomography
# Fluorescence molecular tomographic image reconstruction based on reduced measurement data
# Small animal fluorescence and bioluminescence tomography: a review of approaches, algorithms and technology update.
# Efficient reconstruction method for L1 regularization in fluorescence molecular tomography
# Reconstruction for limited-projection fluorescence molecular tomography based on projected restarted conjugate gradient normal residual.
#
# File ID: 590
# Question: Star formation rates studies published by National University of Rwanda researchers
# bm25 Nodes: National University of Rwanda
# Observation of phase boundaries in spontaneous optical pattern formation
# The dynamical evolution of molecular clouds near the Galactic Centre -- III. Tidally--induced star formation in protocluster clouds
# The star formation history of mass-selected galaxies from the VIDEO survey
# A Comparative Study of Knots of Star Formation in Interacting vs. Spiral Galaxies
# Major mergers are not significant drivers of star formation or morphological transformation around the epoch of peak cosmic star formation
# Calibration of ultraviolet, mid-infrared and radio star formation rate indicators
# Testing 24 μm and Infrared Luminosity as Star Formation Tracers for Galactic Star-forming Regions
# X-ray insights into star and planet formation.
# Ab initio studies of isolated hydrogen vacancies in graphane
#
# File ID: 652
# Question: Can you show me the papers related to dark matter constraints authored by researchers who also contributed to 'Topology in QCD and the axion abundance'?
# bm25 Nodes: Stochastic axion scenario
# QCD Axion Dark Matter with a Small Decay Constant.
# Hidden axion dark matter decaying through mixing with QCD axion and the 3.5 keV X-ray line
# Mixed axion/neutralino cold dark matter in supersymmetric models
# Cosmological axion and a quark nugget dark matter model
# Mixed axion/neutralino dark matter in the SUSY DFSZ axion model
# Inflaxion Dark Matter
# Mainly) axion dark matter
# Leptogenesis scenarios for natural SUSY with mixed axion-higgsino dark matter
# Tensor Detection Severely Constrains Axion Dark Matter
#
# File ID: 67
# Question: I'm looking for papers in the same study field as "From soft walls to infrared branes", that share a coauthor with it and talk about neutrino masses in their discussion.
# bm25 Nodes: From soft walls to infrared branes
# Weak Lensing Data and Condensed Neutrino Objects
# Icecube/DeepCore tests for novel explanations of the MiniBooNE anomaly.
# Matching the linear spectra of twinlike defects
# Sterile neutrino fits to dark matter mass profiles in the Milky Way and in galaxy clusters
# Radiative corrections to $M_h$ from three generations of Majorana neutrinos and sneutrinos
# Fermion masses and mixing with tri-bimaximal in SO(10) with type-I seesaw
# Looking for Intermediate-Mass Black Holes
# Radiative Scaling Neutrino Mass with A 4 Symmetry
# Swiss-cheese D3–D7 soft SUSY breaking
#
# File ID: 318
# Question: Are there any publications linked to the Pittsburgh Supercomputing Center focusing on the impact of Reynolds number on nozzles in computational fluid dynamics?
# bm25 Nodes: Supersonic Retropropulsion Computational Fluid Dynamics Validation with Langley 4×4 Foot Test Data
# Pittsburgh Supercomputing Center
# CFD Study of Effects of Geometry Variations on Flow in a Nozzle
# Development of an Aeroelastic Modeling Capability for Transient Nozzle Flow Analysis
# Computational Fluid Dynamics Study on Forced Convective Heat Transfer Phenomena of Spheres in Power-law Liquids with Velocity Slip at the Interface
# Hole number effect on spray dynamics of multi-hole diesel nozzles: An observation from three- to nine-hole nozzles
# Three-Dimensional Simulation of Fluid Flow and Energy Separation Inside a Vortex Tube
# Numerical study of the parameters governing the impact dynamics of yield-stress fluid droplets on a solid surface
# Application of a Reynolds-Averaged Navier–Stokes Approach to Supersonic Retropropulsion Flowfields
# Computational Fluid Dynamics Modeling of Benjamin and Taylor Bubbles in Two-Phase Flow in Pipes
#
# File ID: 753
# Question: Show me publications by V. G. Boutko that focus on the study of magnetic characteristics in iron nanowires.
# bm25 Nodes: V. G. Boutko
# Control of Magnetic Properties of Carbon Nanotubes Filled with Iron
# Electronic and optical properties of core-shell nanowires in a magnetic field.
# Size effects on the magnetoelectric response on PVDF/Vitrovac 4040 laminate composites
# First principles study on the electronic structure and effect of vanadium doping of BN nanowires
# Highly zero-biased magnetoelectric response in magnetostrictive/piezoelectric composite
# Morphology-dependent field emission characteristics of SiC nanowires
# Evolution of the electronic structure and optical properties of iron-based Heusler alloys
# Reorientation mechanisms and pseudoelasticity in iron nanowires
# Magnetoelectric coupling characteristics of five-phase laminate composite transducers based on nanocrystalline soft magnetic alloy
#
# File ID: 436
# Question: I'm looking for papers that share a coauthor with "Over three-octave spanning supercontinuum generated in a fluoride fiber pumped by Er & Er:Yb-doped and Tm-doped fiber amplifiers". These papers should be in the realm of mid-infrared supercontinuum generation and present the initial modelocked laser pulses at 2 μm wavelength.
# bm25 Nodes: Over three-octave spanning supercontinuum generated in a fluoride fiber pumped by Er & Er:Yb-doped and Tm-doped fiber amplifiers
# Mid-infrared supercontinuum generation in tapered chalcogenide fiber for producing octave-spanning frequency comb around 3 μm.
# High-spectral-flatness mid-infrared supercontinuum generated from a Tm-doped fiber amplifier
# Supercontinuum generation in quasi-phase-matched LiNbO_3 waveguide pumped by a Tm-doped fiber laser system
# Numerical investigation of mid-infrared supercontinuum generation up to 5 μm in single mode fluoride fiber.
# Mid-infrared supercontinuum generation spanning 1.8 octaves using step-index indium fluoride fiber pumped by a femtosecond fiber laser near 2 µm.
# Mid-IR supercontinuum pumped by femtosecond pulses from thulium doped all-fiber amplifier
# The generation of a broadband, spectrally flat supercontinuum extended to the mid-infrared with the use of conventional passive single-mode fibers and thulium-doped single-mode fibers pumped by 1.55 μm pulses
# High-power short-wavelength infrared supercontinuum generation in multimode fluoride fiber
# Octave-spanning supercontinuum generation in in situ tapered As_2S_3 fiber pumped by a thulium-doped fiber laser
#
# File ID: 88
# Question: Find articles on Arxiv from University of Asia and the Pacific authors about the crystallization process and soft magnetic properties of materials.
# bm25 Nodes: Significant improvement of soft magnetic properties for Fe-based nanocrystalline alloys by inhibiting surface crystallization via a magnetic field assisted melt-spinning process
# University of Asia and the Pacific
# Effect of surface crystallization on magnetic properties of Fe82Cu1Si4B11.5Nb1.5 nanocrystalline alloy ribbons
# APTWG: The 4th Asia-Pacific Transport Working Group Meeting
# Effect of pre-crystallization on the preparation of thick Bi-YIG films by the metal–organic decomposition method
# Effect of Fe to P concentration ratio on structures, crystallization behavior, and magnetic properties in (Fe0.79+xP0.1−xC0.04B0.04Si0.03)99Cu1 alloys
# Effect of P addition on glass forming ability and soft magnetic properties of melt-spun FeSiBCuC alloy ribbons
# Formation of soft magnetic high entropy amorphous alloys composites containing in situ solid solution phase
# Effect of crystallization on soft magnetic properties of nanocrystalline Fe80B10Si8Nb1Cu1 alloy
# Influence of Al and Ni on the magnetic properties of Finemet alloys
#
# File ID: 63
# Question: Could you find papers that discuss narrow-band emission and either cite or are cited by the study "Powerful linearly-polarized high-order random fiber laser pumped by broadband amplified spontaneous emission source"?
# bm25 Nodes: Powerful linearly-polarized high-order random fiber laser pumped by broadband amplified spontaneous emission source.
# Incoherently pumped high-power linearly-polarized single-mode random fiber laser: experimental investigations and theoretical prospects
# Band selective C- or L-band ASE source using unpumped erbium-doped fiber with an optical switch
# Self-pulsing in a large mode area, end-pumped, double-clad ytterbium-doped fiber laser
# A high-power LD-pumped linearly polarized Yb-doped fiber laser operating at 1152 nm with 42 GHz narrow linewidth and 18 dB PER
# A powerful broadband Ho-doped fiber source in the 2 μm region
# Power scalability of a single-stage Yb-doped superfluorescent fiber source
# High power narrow-band fiber-based ASE source
# Influences of position of ytterbium-doped fiber and ASE pump on spectral properties of random fiber laser
# Spontaneous and induced modulation instability in the presence of broadband spectra caused by the amplified spontaneous emission
#
# File ID: 351
# Question: Find other publications from the co-authors of "Decaying Dark Atom constituents and cosmic positron excess" that delve into the subject of early universe reionization.
# bm25 Nodes: Decaying Dark Atom constituents and cosmic positron excess
# Dynamical Dark Matter and the positron excess in light of AMS results
# AMS-02 Positron Excess and Indirect Detection of Three-body Decaying Dark Matter
# Decaying WIMP dark matter for AMS-02 cosmic positron excess
# Cosmic Microwave Background constraints of decaying dark matter particle properties
# The Dark Ages of the Universe and Hydrogen Reionization
# PAMELA's cosmic positron from decaying LSP in SO(10) SUSY GUT
# Secondary Production as the Origin of the Cosmic-ray Positron Excess
# Secondary Cosmic Positrons in an Inhomogeneous Diffusion Model
# Reionization and dark matter decay
#
# File ID: 936
# Question: Could you find any papers written by Yan Xu focusing on the research of the impact of additives? I'm particularly interested in those which offer an analysis of the effects of these additives.
# bm25 Nodes: Fire extinct experiments with water mist by adding additives
# The diminishment of specific heat and surface tension of coolant droplet in a dropwise evaporation process: A novel methodology to enhance the heat transfer rate
# Effects of KCl Additives on Structure, Phase Transitions and Dielectric Properties of 0.36BiScO3 - 0.64PbTiO3 Ceramics
# The spectral analysis of fuel oils using terahertz radiation and chemometric methods
# The effect of cobalt additives on martensitic transformations and deformation in sintered porous nickel titanium alloys
# Introduction of co-additives to form well dispersed photoactive layer to improve performance and stability of organic solar cells
# Experimental comparative study on the performance of nano-SiO2 and microsilica in stabilization of clay
# Effects of solvent additives on trap‐assisted recombination in P3HT:ICBA based polymer solar cells
# Effect of halogen-terminated additives on the performance and the nanostructure of all-polymer solar cells
# Raising efficiency of organic solar cells with electrotropic additives
#
# File ID: 635
# Question: Show me publications by Ming Li that enhance quantum entanglement limits.
# bm25 Nodes: Entanglement of Formation for Multipartite k-Nonseparable States
# Dynamics of the Bipartite and Multipartite Entanglement in the Heisenberg Chain with Dzyaloshinskii-Moriya Interaction
# Sensitivity Bounds for Multiparameter Quantum Metrology.
# Distributed quantum sensing using continuous-variable multipartite entanglement
# Symmetry Protection of Photonic Entanglement in the Interaction with a Single Nanoaperture.
# Quantum-enhanced sensing from hyperentanglement
# Quantum estimation in neutrino oscillations
# Enhancing Robustness of Entanglement in Finite Temperature Environment Using Quantum Measurement Reversal
# Extended negativity measure for multipartite k-nonseparable states
# Persistence of entanglement in thermal states of spin systems
#
# File ID: 644
# Question: Show me the papers by Infant Solomon that explore the topic of magnetized plasma oscillations.
# bm25 Nodes: Infant Solomon
# Alfvénic tornadoes in a magnetized plasma
# Wave breaking of nonlinear electron oscillations in a warm magnetized plasma
# SO-FDTD analysis on the stealth effect of magnetized plasma with Epstein distribution
# Comparative study on nonlinear dynamics of magnetized and un-magnetized dc glow discharge plasma
# Nonlinear Plasma Wave in Magnetized Plasmas
# Characteristics of slow light in a magnetized plasma hyperbolic metamaterial waveguide
# Nonlinear lower-hybrid oscillations in cold plasma
# Nonlinear electrostatic oscillations in a cold magnetized electron-positron plasma
# Experimental and numerical study of electromagnetically induced transparency in magnetized plasmas
#
# File ID: 554
# Question: Show me papers from Taiz University researchers covering the topic of polymer thermo-optic switches and their related applications.
# bm25 Nodes: Advance in thermo-optical switches: principles, materials, design, and device structure
# N × N polymer matrix switches using thermo-optic total-internal-reflection switch.
# Thermo-optic devices on polymer platform
# Simultaneous measurement of thermo-optic and stress-optic coefficients of polymer thin films using prism coupler technique.
# Polymer optical waveguide devices for mode-division-multiplexing applications
# Printable thermo-optic polymer switches utilizing imprinting and ink-jet printing
# Thermo-optic simulations of silicon nitride / polymer hybrid waveguides
# A review on applications of magnetoelectric composites: from heterostructural uncooled magnetic sensors, energy harvesters to highly efficient power converters
# Thermo-optic plasmo-photonic mode interference switches based on dielectric loaded waveguides
# Graphene-embedded first-order mode polymer Mach–Zender interferometer thermo-optic switch with low power consumption
#
# File ID: 917
# Question: Can you suggest some papers on Iridium Radioisotopes with a focus on dose calculation methods?
# bm25 Nodes: Iridium Radioisotopes
# Alpha spectroscopy for in-situ liquid radioisotope measurements
# 'Intractable and unsolved': some thoughts on statistical data assimilation with uncertain static parameters.
# Dosimetric evaluation of intrafractional tumor motion by means of a robot driven phantom.
# Hybrid dose calculation: a dose calculation algorithm for microbeam radiation therapy
# The effect of tomotherapy imaging beam output instabilities on dose calculation.
# Improved CD control for 45-40 nm CMOS logic patterning: anticipation for 32-28 nm
# Dose specification for radiation therapy: dose to water or dose to medium?
# Approaches to reducing photon dose calculation errors near metal implants
# Equations for CT dose calculations on axial lines based on the principle of symmetry
#
# File ID: 432
# Question: Show me papers by W. Panduro Vazquez on multi-pion channel measurements.
# bm25 Nodes: W. Panduro Vazquez
# W. Panduro Vazquez
# William Panduro Vazquez
# J. G. Panduro Vazquez
# Jose Guillermo Panduro Vazquez
# Experimental research on multichannel discharge circuit and multi-electrode plasma synthetic jet actuator
# Electron temperature profile reconstructions from multi-energy SXR measurements using neural networks
# Multiplied magnetoelectric effect in multi-faceted magnetoelectric composite
# On multi-channel operation of phase-preserving 2R amplitude regenerator
# Branching ratios for the decay of d*(2380)
#
# File ID: 978
# Question: What are some papers referenced in "Class I Methanol (CH$_{3}$OH) Maser Conditions near Supernova Remnants" that also delve into the topic of molecular clouds in the Galactic center?
# bm25 Nodes: Class I Methanol (CH$_{3}$OH) Maser Conditions near Supernova Remnants
# DETECTION OF CLASS I METHANOL (CH3OH) MASER CANDIDATES IN SUPERNOVA REMNANTS
# 44 GHz Class I Methanol (CH$_{3}$OH) Maser Survey in the Galactic Center
# Search for class I methanol maser emission toward several supernova remnants
# NH$_3$(3,3) and CH$_3$OH near Supernova Remnants: GBT and VLA Observations
# Class I methanol maser emission in infrared clouds and the third version of the Astro Space Center MMI/SFR catalog
# High resolution OH observations of Extended Green Objects
# High-mass star-forming cloud G0.38+0.04 in the Galactic Center Dust Ridge contains H2CO and SiO masers
# Class I Methanol Emission Around DR 21 (OH)
# Detection of HC$_3$N maser emission in NGC253
#
# File ID: 294
# Question: What papers discussing electron characteristics reference or are referenced by the study on whistler mode waves in connection with Saturn's magnetosphere's ring distribution function?
# bm25 Nodes: Electron acceleration by Z-mode and whistler-mode waves
# Study of relativistic beam of electron on whistler mode waves for subtracted distribution in Saturnian magnetosphere
# Study of whistler mode waves for ring distribution function in Saturn’s magnetosphere
# A 2D simulation study of Langmuir, whistler, and cyclotron maser instabilities induced by an electron ring-beam distribution
# Study of VLF wave with relativistic effect in Saturn magnetosphere in the presence of parallel A.C. electric field
# Analytical study of Whistler mode waves for relativistic plasma with AC electric field in inner magnetosphere of Saturn
# Intense plasma wave emissions associated with Saturn's moon Rhea
# The relationship between the macroscopic state of electrons and the properties of chorus waves observed by the Van Allen Probes
# Whistler wave generation by electron temperature anisotropy during magnetic reconnection at the magnetopause
# Whistler mode waves for ring distribution with A.C. electric field in inner magnetosphere of Saturn
#
# File ID: 425
# Question: What are the papers cited by "Black hole thermodynamical entropy" that also delve into the nonlinear generalization of the Schrödinger equation and were published in 2012?
# bm25 Nodes: AdS Black Hole with Phantom Scalar Field
# Productivity and impact of astronomical facilities: A recent sample
# Thermodynamical universality of the Lovelock black holes
# Thermodynamics and phase transition of the Reissner–Nordström black hole surrounded by quintessence
# Black Hole Thermodynamics Under the Microscope
# Black hole entropy production and transport coefficients in Lovelock gravity
# Thermodynamical Metrics and Black Hole Phase Transitions
# Thermodynamical Stability of a New Regular Black Hole
# A class of black holes in dRGT massive gravity and their thermodynamical properties
# Kerr–Newman black hole thermodynamical state space: blockwise coordinates
#
# File ID: 713
# Question: Publications on atomic-scale dynamics by authors affiliated with Sri Sivasubramaniya Nadar College of Engineering
# bm25 Nodes: Sri Sivasubramaniya Nadar College of Engineering
# Sri Venkateswara College of Engineering
# Sri Krishna College of Engineering & Technology
# Sri Ramakrishna Engineering College
# Sri Manakula Vinayagar Engineering College
# Ayya Nadar Janaki Ammal College
# Sri Venkateswara College
# Sri Pratap College
# A.V.V.M Sri Pushpam College
# Cooperation and coauthorship in scientific publishing.
#
# File ID: 260
# Question: Publications on vortex instabilities authored by Farmingdale State College researchers
# bm25 Nodes: Farmingdale State College
# Three-dimensional instability on the interaction between a vortex and a stationary sphere
# Negative velocity fluctuations and non-equilibrium fluctuation relation for a driven high critical current vortex state
# Phenomena, dynamics and instabilities of vortex pairs
# Equilibration of centrifugally unstable vortices: A review
# Perturbations of vortex ring pairs
# Onset, evolution, and magnetic braking of vortex lattice instabilities in nanostructured superconducting films
# The citation wake of publications detects nobel laureates' papers.
# Elliptical vortex necklaces in Mathieu lattices
# Josephson Vortex Qubit based on a Confocal Annular Josephson Junction
#
# File ID: 583
# Question: Search for papers by K. Held on phase separation in transition metal oxides.
# bm25 Nodes: Superstripes and Percolating Nanoscale-Striped Puddles in Heterostructures at Atomic Limit
# Insulator/metal phase transition and colossal magnetoresistance in holographic model
# Metal-insulator transition in epitaxial V1−xWxO2(0≤x≤0.33) thin films
# Metal-insulator transition and nonlinear optical responseof sputter-deposited V3O5 thin films
# Universal Behaviors of the Phonon Thermal Conductivity Associated with Charge/Orbital Ordering in Transition-Metal Oxides
# Conditions of Morphotropic Phase Boundary in Perovskite-Oxides
# Quantified degeneracy, entropy, and metal-insulator transition in complex transition-metal oxides
# Competing exotic topological insulator phases in transition-metal oxides on the pyrochlore lattice with distortion
# Ferrimagnetism and magnetic phase separation in Nd1-xYxMnO3 studied by magnetization and high frequency electron paramagnetic resonance
# Resonances and Complexity: From Stripes to Superstripes
#
# File ID: 445
# Question: Publications on dark energy models by authors affiliated with Bhairab Ganguly College
# bm25 Nodes: Bhairab Ganguly College
# Cooperation and coauthorship in scientific publishing.
# A gauge-invariant approach to interactions in the dark sector
# Post-Planck Dark Energy Constraints
# Late evolution of relic gravitational waves in coupled dark energy models
# Understanding the origin of CMB constraints on dark energy
# Can Holographic dark energy models fit the observational data
# Constraints on interacting dark energy models from Planck 2015 and redshift-space distortion data
# Kaluza Klein universe with magnetized anisotropic dark energy in general relativity and Lyra manifold
# Effects of tidal gravitational fields in clustering dark energy models
#
# File ID: 265
# ...
# Scattering of Ultra-relativistic Electrons in the Van Allen Radiation Belts Accounting for Hot Plasma Effects.
#
# File ID: 510
# Question: Search for papers from 2014 in the same discipline as "Measurement of resonant and nonresonant induced refractive index changes in Yb-doped fiber grating amplifier," that have a common coauthor and describe a novel photonic ADC technique.
# bm25 Nodes: Measurement of resonant and nonresonant induced refractive index changes in Yb-doped fiber grating amplifier.
# Modal energy transfer by thermally induced refractive index gratings in Yb-doped fibers
# Measurement of $\gamma$ -Radiation Induced Refractive Index Changes in B/Ge Doped Fiber Using LPGs
# Yb band parasitic lasing suppression in Er/Yb-co-doped pulsed fiber amplifier based on all-solid photonic bandgap fiber
# Simultaneous measurement of refractive index and temperature using dual-period grapefruit microstructured fiber grating
# Concentration and refractive index sensor for methanol using short period grating fiber
# Tunable Fractional Order Temporal Differentiator by Optically Pumping a Tilted Fiber Bragg Grating
# Thermally induced mode instability in high power fiber amplifiers
# Long period fiber grating formed by periodically structured microholes in all-solid photonic bandgap fiber.
# Fiber amplifier utilizing an Yb-doped large-mode-area fiber with confined doping and tailored refractive index profile
#
# File ID: 856
# Question: Which studies about asteroids are credited to authors associated with the Tokyo Metropolitan Government?
# bm25 Nodes: Tokyo Metropolitan Government
# Absorbed dose rate in air in metropolitan Tokyo before the Fukushima Daiichi Nuclear Power Plant accident.
# Tokyo Metropolitan University
# Seoul Metropolitan Government
# Comparison of the Impact of Global Climate Changes and Urbanization on Summertime Future Climate in the Tokyo Metropolitan Area
# Experimental setup and procedure for the measurement of the 7Be(n,p)7Li reaction at n_TOF
# The Tokyo axion helioscope
# Spectral properties of the largest asteroids associated with Taurid Complex
# Performance of Long-Distance Quantum Key Distribution Over 90-km Optical Links Installed in a Field Environment of Tokyo Metropolitan Area
# Constraints on chiral operators in N=2 SCFTs
#
# File ID: 252
# Question: Does Tunku Abdul Rahman University College have any physics papers demonstrating optical delay techniques?
# bm25 Nodes: Tunku Abdul Rahman University College
# Universiti Tunku Abdul Rahman
# Princess Nora bint Abdul Rahman University
# Abdul Rahim Abdul Rahman
# Abdul Rahman Mohmad
# Saadah Abdul Rahman
# Abdul Rahman Mohamed
# Zulkanain Abdul Rahman
# N. Abdul Rahman
# Houssam Abdul-Rahman
#
# File ID: 21
# Question: List papers discussing shock wave solution behaviors in the context of weak solutions.
# bm25 Nodes: Note on the single-shock solutions of the Korteweg-de Vries-Burgers equation
# Acceleration of weak shock waves
# Shock wave triple-point morphology
# Propagation of weak shock waves in non-uniform, radiative magnetogasdynamics
# Concentration in vanishing pressure limit of solutions to the modified Chaplygin gas equations
# The Numerical Simulation of General Relativistic Shock Waves by a Locally Inertial Godunov Method Featuring Dynamical Time Dilation
# Computation of weak steady shock reflections by means of an unstructured shock-fitting solver
# Shock wave solutions to the Bogoyavlensky–Konopelchenko equation
# Magnetosonic shock wave in collisional pair-ion plasma
# Shock wave solutions of the variants of the Kadomtsev–Petviashvili equation
#
# File ID: 313
# Question: Which publications from Taki Government College authors focus on examining the fluctuations in X-ray sources?
# bm25 Nodes: Taki Government College
# Variability in ultra-luminous X-ray sources
# Line focus x-ray tubes-a new concept to produce high brilliance x-rays.
# The rich complexity of 21-cm fluctuations produced by the first stars
# Characterization and calibration of a multilayer coated Wolter optic for an imager on the Z-machine at Sandia National Laboratories.
# Near-Infrared Spectroscopy of Faint Discrete X-ray Point Sources Constituting the Galactic Ridge X-ray Emission
# An X-ray survey of the 2 Jy sample - II. X-ray emission from extended structures
# X-Ray and Optical Study of Low Core Density Globular Clusters NGC6144 and E3
# The First Year of S-CUBED: The Swift Small Magellanic Cloud Survey
# X-ray surface brightness and gas density fluctuations in the Coma cluster
#
# File ID: 385
# Question: Could you show me some papers related to the Rectangular function published in 2011?
# bm25 Nodes: Heat transfer—A review of 2004 literature
# Heat transfer—A review of 2005 literature
# Some Remarks on Exp-Function Method and Its Applications
# Current Status of Magnetoelectric Composite Thin/Thick Films
# Topology and gauge theory in physics
# Giant magnetoelectric torque effect and multicoupling in two phases ferromagnetic/piezoelectric system
# Large multiple resonance of magnetoelectric effect in a multiferroic composite cylinder with an imperfect interface
# Bibliometric analysis of fifty years of physica status solidi
# A four-state magnetoelectric coupling for embedded piezoelectric/magnetic composites
# Afterword. Laser-light and interactions with particles (LIP), 2018
#
# File ID: 491
# Question: Show me publications by Nikita M. Bityurin on enhancing the resolution of nanostructures.
# bm25 Nodes: Nikita M. Bityurin
# Anisotropic strain, magnetic properties, and lattice dynamics in self-assembled multiferroic CoFe2O4-PbTiO3 nanostructures
# Present status of theoretical modeling the magnetoelectric effect in magnetostrictive-piezoelectric nanostructures. Part I: Low frequency and electromechanical resonance ranges
# N M Bityurin
# Enhancing the magnetoelectric response of Terfenol-D/polyvinylidene fluoride/Terfenol-D laminates by exploiting the shear mode effect
# Enhancing magnetoelectric effect via the curvature of composite cylinder
# Tutorial: Product properties in multiferroic nanocomposites
# Applicability of Milne-Eddington inversions to high spatial resolution observations of the quiet sun
# High resolution fabrication of nanostructures using controlled proximity nanostencil lithography
# High Magnetoelectric Coupling in Nano–Microscale Particulate Composites at Low Frequency
#
# File ID: 663
# Question: Search for publications by Joseph E. Golec focusing on the scientific objectives of future cosmic microwave background studies.
# bm25 Nodes: Joseph E. Golec
# Cosmic Microwave Background science from Dome C
# Canny Algorithm, Cosmic Strings and the Cosmic Microwave Background
# Tilted physics: A cosmologically dipole-modulated sky
# RECENT DEVELOPMENTS IN ASTROPHYSICAL AND COSMOLOGICAL EXPLOITATION OF MICROWAVE SURVEYS
# An All Silicon Feedhorn-Coupled Focal Plane for Cosmic Microwave Background Polarimetry
# Cosmic microwave background and cosmic polarization rotation: An experimentalist view
# Isocurvature modes and Baryon Acoustic Oscillations II: gains from combining CMB and Large Scale Structure
# Modulation of cosmic microwave background polarization with a warm rapidly rotating half-wave plate on the Atacama B-Mode Search instrument
# Cosmic-Ray Extremely Distributed Observatory: status and perspectives
#
# File ID: 871
# Question: Search for articles with a common author as "Pressure in Lemaïtre-Tolman-Bondi solutions and cosmologies", which are from the same discipline, and also explore the topic of central orbits in potentials.
# bm25 Nodes: Pressure in Lema\^{i}tre-Tolman-Bondi solutions and cosmologies
# Separating expansion from contraction: generalized TOV condition, LTB models with pressure and $\Lambda$CDM
# Exact solutions of Schrödinger and Pauli equations for a charged particle on a sphere and interacting with non-central potentials
# Radiating Bondi and Cooling Site Flows
# QUANTUM GRAVITATIONAL COLLAPSE IN THE LEMAITRE-TOLMAN-BONDI MODEL WITH A POSITIVE COSMOLOGICAL CONSTANT
# Lemaitre-Tolman-Bondi dust solutions in f(R) gravity
# Lemaitre-Tolman-Bondi Model of the Universe and Hawking Radiation of a Dynamical Horizon
# Exact solutions of a spin-orbit coupling model in two-dimensional central-potentials and quantum-classical correspondence
# Electromagnetic field and dynamics of tilted Lemaitre-Tolman-Bondi spacetimes
# Cosmic censorship conjecture in some matching spherical collapsing metrics
#
# File ID: 372
# Question: Papers by Joonbum Park on the impact of stress on magnetic phase transitions
# bm25 Nodes: Joonbum Park
# Joonbum Park
# Magnetic configuration effects on the Reynolds stress in the plasma edge
# Strain effects in GaN epilayers grown on different substrates by metal organic vapor phase epitaxy
# Nonlinear stress-strain behavior and stress-induced phase transitions in soft Pb(Zr 1-x Ti x )O 3 at the morphotropic phase boundary
# Impact of local compressive stress on the optical transitions of single organic dye molecules
# Simulation of Magnetic Field Abnormalities Caused by Stress Concentrations
# Influence of Biaxial Stress on Magnetic Behavior of Dual-Phase Steel—Experiments and Modeling
# Phase transitions in classical biquadratic Heisenberg model for strained iron pnictides
# Notes on phase transitions and the role of spin fluctuations
#
# File ID: 458
# Question: Does Arxiv have any physics papers from Algonquin College related to the generation of vector optical fields?
# bm25 Nodes: Algonquin College
# Vector optical field generation based on birefringent phase plate
# Manipulation of dielectric Rayleigh particles using highly focused elliptically polarized vector fields.
# Simultaneous generation of multiple vector beams on a single SLM.
# Superform formulation for vector-tensor multiplets in conformal supergravity
# Twisted vector field from an inhomogeneous and anisotropic metamaterial
# Pseudo-topological property of Julia fractal vector optical fields
# Elliptic-symmetry vector optical fields
# Versatile generation of optical vector fields and vector beams using a non-interferometric approach.
# Fractal vector optical fields
#
# File ID: 121
# Question: Could you locate articles whose one author has also contributed to "Axonic Au Tips Induced Enhancement in Raman Spectra and Biomolecular Sensing", have a focus in the area of graphene-enhanced plasmonic biosensing, and offer a similar discussion on graphene's enhancement of plasmonic sensing as seen in the original paper?
# bm25 Nodes: Axonic Au Tips Induced Enhancement in Raman Spectra and Biomolecular Sensing
# Graphene–bimetal plasmonic platform for ultra-sensitive biosensing
# Development of Nanostructured Plasmonic Substrates for Enhanced Optical Biosensing
# Transverse excitation of plasmonic slot nano-resonators embedded in metal-coated plasmonic microfiber tips
# Ultrasensitive Plasmonic Detection of Molecules with Graphene
# Band-edge Bilayer Plasmonic Nanostructure for Surface Enhanced Raman Spectroscopy
# Near-Field Optical Analysis of Plasmonic Nano-Probes for Top-Illumination Tip-Enhanced Raman Scattering
# Tunable mid-infrared graphene-titanium nitride plasmonic absorber for chemical sensing applications
# TM plasmonic modes in a multilayer graphene-dielectric structure
# Optical trapping and sensing with plasmonic dipole antennas
#
# File ID: 614
# Question: Show me publications by Hongqing Zhang introducing novel approaches to nonlinear equation resolution.
# bm25 Nodes: Hongqing Zhang
# Residual symmetry reductions and interaction solutions of the (2+1)-dimensional Burgers equation*
# Nonlinear magnetoelectric effect and magnetostriction in piezoelectric CsCuCl3 in paramagnetic and antiferromagnetic states
# Magnetoelectric effects in a layered ferromagnet-electrostrictor heterostructure
# Binary simplest equation method to the generalized Sinh–Gordon equation
# The improved fractional sub-equation method and its applications to the space-time fractional differential equations in fluid mechanics ✩
# Influence of metglas layer on nonlinear magnetoelectric effect for magnetic field detection by frequency modulation
# Nonlinear magnetoelectric effect in PZT/Terfenol-D nanobilayer on a substrate with surface stress
# New optical solitons of nonlinear conformable fractional Schrödinger-Hirota equation
# Linear and nonlinear magnetoelectric effects in lead zirconate titanate–nickel ferrite bulk composites
#
# File ID: 20
# Question: Publications on numerical heat transfer modeling by authors affiliated with Instituto Tecnológico de Saltillo
# bm25 Nodes: Instituto Tecnológico de Saltillo
# Instituto Tecnológico de Mérida
# Instituto Tecnológico de Morelia
# Instituto Tecnológico de Aeronáutica
# Instituto Tecnológico de Querétaro
# Instituto Tecnológico de Buenos Aires
# Instituto Tecnológico Superior de Irapuato
# Instituto Tecnológico Autónomo de México
# Instituto Tecnológico de Santo Domingo
# Instituto Tecnológico Superior de Zacapoaxtla
#
# File ID: 270
# Question: What research has been referenced in the "Polarization-dependent femtoscond laser ablation of poly-methyl methacrylate" paper that also pertains to the study on fused silica damage morphology?
# bm25 Nodes: Polarization-dependent femtosecond laser ablation of poly-methyl methacrylate
# Effect of annealing on the laser induced damage of polished and CO2 laser-processed fused silica surfaces
# The role of defects in laser-induced modifications of silica coatings and fused silica using picosecond pulses at 1053 nm: I. Damage morphology.
# Role of defects in laser-induced modifications of silica coatings and fused silica using picosecond pulses at 1053 nm: II. Scaling laws and the density of precursors.
# Origin of the damage ring pattern in fused silica induced by multiple longitudinal modes laser pulses
# Effect of HF etching on the surface quality and laser-induced damage of fused silica
# Impact of two CO(2) laser heatings for damage repairing on fused silica surface.
# Subsurface defects of fused silica optics and laser induced damage at 351 nm
# Particle damage sources for fused silica optics and their mitigation on high energy laser systems
# Investigation on Laser Damage Probability of Fused Silica with Simultaneous Multi-wavelength Irradiation
#
# File ID: 435
# Question: Papers on black hole characteristics and gravitational lensing by authors from Technical University of Sofia
# bm25 Nodes: Strong gravitational lensing in a charged squashed Kaluza-Klein black hole
# Gravitational lensing by black holes
# Relationship between high-energy absorption cross section and strong gravitational lensing for black hole
# Strong Gravitational Lensing in a Brane-World Black Hole
# Strong field gravitational lensing in stringy black hole
# Effect of gravitational lensing on the distribution of gravitational waves from distant binary black hole mergers
# Strong gravitational lensing by wormholes
# Probing spacetime noncommutative constant via charged astrophysical black hole lensing
# Strong field gravitational lensing by a charged Galileon black hole
# Effects of Homogeneous Plasma on Strong Gravitational Lensing of Kerr Black Hole
#
# File ID: 102
# Question: What are the papers referenced by "Dislocation nucleation from symmetric tilt grain boundaries in body-centered cubic vanadium" that also delve into the subject of fusion materials?
# bm25 Nodes: Dislocation nucleation from symmetric tilt grain boundaries in body-centered cubic vanadium
# Atomistic simulations of effect of hydrogen atoms on mechanical behaviour of an α-Fe with symmetric tilt grain boundaries
# Hierarchical dislocation nucleation controlled by internal stress in nanocrystalline copper
# Investigation of nucleation processes during dynamic recrystallization of ice using cryo-EBSD
# Dislocation nucleation governed softening and maximum strength in nano-twinned metals
# Crossing grain boundaries in metals by slip bands, cleavage and fatigue cracks.
# Helium segregation and transport behavior near ⟨100⟩ and ⟨110⟩ symmetric tilt grain boundaries in tungsten
# Energetics of vacancy segregation to symmetric tilt grain boundaries in hexagonal closed pack materials
# Influence of coherent nanoinclusions on stress-driven migration of low-angle grain boundaries in nanocomposites
# Atomistic study on the strength of symmetric tilt grain boundaries in graphene
